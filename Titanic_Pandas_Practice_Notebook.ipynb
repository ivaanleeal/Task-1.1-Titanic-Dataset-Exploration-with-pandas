# %% [markdown]
# # 🧩 Titanic Dataset Exploration with pandas
#
# 🎯 **Goal:**
# In this notebook, you'll explore the Titanic dataset using **pandas**.
# You'll practice the most common pandas functions for data inspection, selection, filtering, cleaning, and analysis.
#
# For each function in the list below:
# 1. Explain what it does (in your own words, in a Markdown cell).
# 2. Give at least **two examples** using the Titanic dataset.
# 3. Add a short comment about the output or why it’s useful.

# %%
import pandas as pd

# Load Titanic dataset
# (Make sure titanic.csv is in the same folder as this notebook)
df = pd.read_csv("titanic_dataset.csv")

# Show first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 🧠 Step 1: Inspecting the Data
#
# Functions to explore:
# - df.head()
# - df.tail()
# - df.info()
# - df.describe()
# - df.shape
# - df.columns

# %% [markdown]
# # Explicación método head
# El método head nos imprime los primeros datos del archivo csv.

# %%
# Example: df.head()
df.head()

# Example 2
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# El metodo devuelve las primeras filas del csv, en la segunda llamada imprime las 10 primeras, este método sirve para una vez tengamos el archivo csv podamos ver su contenido y hacernos una idea de su contenido.

# %% [markdown]
# # Explicación método tail
# El método tail nos imprime los últimos datos del archivo csv.

# %%
# Ejemplo:
df.tail()

# Ejemplo 2:
df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %% [markdown]
# El metodo devuelve las últimas filas del csv, en la segunda llamada imprime las 7 últimas, este método sirve para una vez tengamos el archivo csv podamos ver su contenido y hacernos una idea de su contenido.

# %% [markdown]
# # Explicación método info
# El método info nos imprime información general del archivo csv, como las columnas la cantidad de datos, el tipo de datos de cada uno etc.

# %%
# Ejemplo:
df.info()

# Ejemplo 2:
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# El método devuelve información general sobre los datos del archivo csv los cuales nos sirven para saber como tratar los datos de este.

# %% [markdown]
# # Explicación método describe
# El método describe nos permite tener un resúmen de las estadísticas del csv

# %%
# Ejemplo:
df.describe()

# Ejemplo 2:
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# El método devuelve informacion de por ejemplo el máximo de cada columna, minimo etc lo cual nos puede ayudar en caso de querer buscar estadísticas.

# %% [markdown]
# # Explicación método shape
# El método shape nos dice cuantas filas y columnas tiene el csv.

# %%
# Ejemplo:
df.shape

# Ejemplo 2:
# Out:
# (891, 12)

# %% [markdown]
# Nos vale para saber cuantos datos (filas columnas) tiene el csv de manera rápida.

# %% [markdown]
# # Explicación método columns
# El método columns nos devuelve las columnas que tiene el csv en forma de lista.

# %%
# Ejemplo:
df.columns

# Ejemplo 2:
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# El método columns nos vale para ver el nombre y el orden de las columnas de nuestro csv.

# %% [markdown]
# ## 🔍 Step 2: Selecting Data
#
# Functions to explore:
# - df["column"]
# - df[["col1", "col2"]]
# - df.loc[]
# - df.iloc[]

# %%
# Example: Selecting columns
df["Age"].head()
df[["Sex", "Age", "Survived"]].head()

# %% [markdown]
# ## 🔎 Step 3: Filtering Rows
#
# Functions to explore:
# - df[df["Age"] > 30]
# - df.query("Sex == 'female' and Survived == 1")

# %%
# Example: Filtering data
df[df["Age"] > 50].head()
df.query("Sex == 'female' and Survived == 1").head()

# %% [markdown]
# ## 🧹 Step 4: Handling Missing Data
#
# Functions to explore:
# - df.isna()
# - df.isna().sum()
# - df.dropna()
# - df.fillna()

# %%
# Example: Check missing values
df.isna().sum()

# Fill missing ages with median
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Age"].head()

# %% [markdown]
# ## 📊 Step 5: Grouping and Aggregating
#
# Functions to explore:
# - df.groupby("Sex")["Survived"].mean()
# - df["Fare"].mean()
# - df["Age"].median()

# %%
# Example: Aggregation
df.groupby("Sex")["Survived"].mean()
df.groupby("Pclass")["Fare"].mean()

# %% [markdown]
# ## 📈 Step 6: Sorting and Counting
#
# Functions to explore:
# - df.sort_values("Age")
# - df["Sex"].unique()
# - df["Pclass"].value_counts()

# %%
# Example: Sorting and counting
df.sort_values("Age").head()
df["Pclass"].value_counts()

# %% [markdown]
# ## ⚙️ Step 7: Creating or Modifying Columns
#
# Functions to explore:
# - df.assign()
# - df.apply()
# - df["new_col"] = ...
# - pd.concat()
# - pd.merge()

# %%
# Example: Create new column
df["Fare_per_Age"] = df["Fare"] / df["Age"]
df[["Age", "Fare", "Fare_per_Age"]].head()

# %% [markdown]
# ## 💾 Step 8: Exporting Data
#
# Function to explore:
# - df.to_csv("output.csv", index=False)

# %%
# Example: Save cleaned data
df.to_csv("titanic_cleaned.csv", index=False)

# %% [markdown]
# ## 🧩 Step 9: Summary
#
# Reflect on what you learned:
# - Which functions were most useful?
# - What insights did you gain from the Titanic dataset?
